# %%
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
airtel = yf.Ticker("LT.NS")
data = airtel.history(period="10y")  # last 1 year
data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2016-03-14 00:00:00+05:30   682.560976   688.063674   671.555631   675.262085
# 2016-03-15 00:00:00+05:30   677.828089   683.045639   670.329616   673.294800
# 2016-03-16 00:00:00+05:30   676.858687   679.538775   664.256680   674.691833
# 2016-03-17 00:00:00+05:30   683.131200   687.122750   675.404640   680.422607
# 2016-03-18 00:00:00+05:30   683.701297   685.982220   678.626322   683.872375
# ...                                ...          ...          ...          ...
# 2026-03-09 00:00:00+05:30  3850.000000  3852.000000  3743.000000  3842.100098
# 2026-03-10 00:00:00+05:30  3936.000000  3972.000000  3851.000000  3876.000000
# 2026-03-11 00:00:00+05:30  3879.699951  3896.699951  3832.000000  3838.800049
# 2026-03-12 00:00:00+05:30  3825.000000  3830.000000  3704.899902  3719.500000
# 2026-03-13 00:00:00+05:30  3696.000000  3697.000000  3424.500000  3439.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2016-03-14 00:00:00+05:30   2726301        0.0           0.0
# 2016-03-15 00:00:00+05:30   2444158        0.0           0.0
# 2016-03-16 00:00:00+05:30   2704711        0.0           0.0
# 2016-03-17 00:00:00+05:30   3872653        0.0           0.0
# 2016-03-18 00:00:00+05:30   2566830        0.0           0.0
# ...                             ...        ...           ...
# 2026-03-09 00:00:00+05:30   4248784        0.0           0.0
# 2026-03-10 00:00:00+05:30   3330102        0.0           0.0
# 2026-03-11 00:00:00+05:30   2066473        0.0           0.0
# 2026-03-12 00:00:00+05:30   4255443        0.0           0.0
# 2026-03-13 00:00:00+05:30  10777943        0.0           0.0
#
# [2471 rows x 7 columns]

# %%
#data.reset_index(inplace=True)

# %%
#data['Date']=pd.to_datetime(data['Date'])

# %%
#data

# %%
#data['Date']=data['Date'].dt.date

# %%
#data['Date']=pd.to_datetime(data['Date'])

# %%
#data.to_excel("ITC.xlsx")

# %%
data.index=pd.to_datetime(data.index)

# %%
data.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2026-03-09 00:00:00+05:30  3850.000000  3852.000000  3743.000000  3842.100098
# 2026-03-10 00:00:00+05:30  3936.000000  3972.000000  3851.000000  3876.000000
# 2026-03-11 00:00:00+05:30  3879.699951  3896.699951  3832.000000  3838.800049
# 2026-03-12 00:00:00+05:30  3825.000000  3830.000000  3704.899902  3719.500000
# 2026-03-13 00:00:00+05:30  3696.000000  3697.000000  3424.500000  3439.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-03-09 00:00:00+05:30   4248784        0.0           0.0
# 2026-03-10 00:00:00+05:30   3330102        0.0           0.0
# 2026-03-11 00:00:00+05:30   2066473        0.0           0.0
# 2026-03-12 00:00:00+05:30   4255443        0.0           0.0
# 2026-03-13 00:00:00+05:30  10777943        0.0           0.0

# %%
plt.figure(figsize=(15,5))
data['Close'].plot()
plt.title("airtel share Trend")
# Out:
# Text(0.5, 1.0, 'airtel share Trend')

# %%
plt.figure(figsize=(15,5))
data['Close'].plot(color = 'green')
plt.xlim("2023-01-01","2026-04-01")
plt.title("airtel share Trend 2024-01-01  to 2026-03-01")
plt.show()

# %% [markdown]
# # Time Resampling

# %%
data.resample('MS').median()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2016-03-01 00:00:00+05:30   686.837637   697.401102   679.838112   685.882477
# 2016-04-01 00:00:00+05:30   705.911673   715.619788   698.726852   709.889130
# 2016-05-01 00:00:00+05:30   733.995365   743.190343   721.892410   734.907776
# 2016-06-01 00:00:00+05:30   841.654138   856.152137   835.809307   847.042786
# 2016-07-01 00:00:00+05:30   895.283899   902.083787   885.148151   894.956055
# ...                                ...          ...          ...          ...
# 2025-11-01 00:00:00+05:30  4004.399902  4026.800049  3978.899902  4002.500000
# 2025-12-01 00:00:00+05:30  4055.500000  4075.400024  4031.799927  4049.650024
# 2026-01-01 00:00:00+05:30  3900.000000  3942.399902  3856.600098  3887.399902
# 2026-02-01 00:00:00+05:30  4181.000000  4202.500000  4150.599854  4193.699951
# 2026-03-01 00:00:00+05:30  3924.199951  3959.000000  3832.000000  3876.000000
#
#                               Volume  Dividends  Stock Splits
# Date
# 2016-03-01 00:00:00+05:30  2800150.5        0.0           0.0
# 2016-04-01 00:00:00+05:30  2526391.0        0.0           0.0
# 2016-05-01 00:00:00+05:30  2468050.0        0.0           0.0
# 2016-06-01 00:00:00+05:30  2394579.5        0.0           0.0
# 2016-07-01 00:00:00+05:30  2060313.0        0.0           0.0
# ...                              ...        ...           ...
# 2025-11-01 00:00:00+05:30  1584741.0        0.0           0.0
# 2025-12-01 00:00:00+05:30  1105662.0        0.0           0.0
# 2026-01-01 00:00:00+05:30  1807300.0        0.0           0.0
# 2026-02-01 00:00:00+05:30  2024853.0        0.0           0.0
# 2026-03-01 00:00:00+05:30  4255443.0        0.0           0.0
#
# [121 rows x 7 columns]

# %%
plt.figure(figsize=(15,5))
data.resample('MS').max()['Close'].plot()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5))
data['Close'].plot()
data['Close'].rolling(14).mean().plot()
plt.title("airtel share Trend")
# Out:
# Text(0.5, 1.0, 'airtel share Trend')

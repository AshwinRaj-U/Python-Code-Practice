# %%
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
airtel = yf.Ticker("BHARTIARTL.NS")
data = airtel.history(period="10y")  # last 1 year
data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2016-03-14 00:00:00+05:30   286.109054   291.956727   283.249259   290.889648
# 2016-03-15 00:00:00+05:30   290.249379   294.090921   286.834697   292.725037
# 2016-03-16 00:00:00+05:30   291.316444   294.346988   286.322434   288.968842
# 2016-03-17 00:00:00+05:30   291.359146   300.237364   288.584712   290.889648
# 2016-03-18 00:00:00+05:30   295.200691   297.292212   290.292070   293.920197
# ...                                ...          ...          ...          ...
# 2026-03-06 00:00:00+05:30  1900.000000  1902.099976  1867.099976  1870.800049
# 2026-03-09 00:00:00+05:30  1831.000000  1872.400024  1818.099976  1866.699951
# 2026-03-10 00:00:00+05:30  1880.800049  1881.000000  1846.500000  1850.400024
# 2026-03-11 00:00:00+05:30  1841.000000  1847.699951  1799.500000  1807.000000
# 2026-03-12 00:00:00+05:30  1797.900024  1817.800049  1791.000000  1805.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2016-03-14 00:00:00+05:30   2633043        0.0           0.0
# 2016-03-15 00:00:00+05:30   2309456        0.0           0.0
# 2016-03-16 00:00:00+05:30   4361912        0.0           0.0
# 2016-03-17 00:00:00+05:30   7155690        0.0           0.0
# 2016-03-18 00:00:00+05:30   3951904        0.0           0.0
# ...                             ...        ...           ...
# 2026-03-06 00:00:00+05:30  10896859        0.0           0.0
# 2026-03-09 00:00:00+05:30   8073518        0.0           0.0
# 2026-03-10 00:00:00+05:30  11741600        0.0           0.0
# 2026-03-11 00:00:00+05:30   9548404        0.0           0.0
# 2026-03-12 00:00:00+05:30   5868933        0.0           0.0
#
# [2470 rows x 7 columns]

# %%
#data.reset_index(inplace=True)

# %%
#data['Date']=pd.to_datetime(data['Date'])

# %%
#data

# %%
#data['Date']=data['Date'].dt.date

# %%
#data['Date']=pd.to_datetime(data['Date'])

# %%
#data.to_excel("ITC.xlsx")

# %%
data.index=pd.to_datetime(data.index)

# %%
data.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2026-03-06 00:00:00+05:30  1900.000000  1902.099976  1867.099976  1870.800049
# 2026-03-09 00:00:00+05:30  1831.000000  1872.400024  1818.099976  1866.699951
# 2026-03-10 00:00:00+05:30  1880.800049  1881.000000  1846.500000  1850.400024
# 2026-03-11 00:00:00+05:30  1841.000000  1847.699951  1799.500000  1807.000000
# 2026-03-12 00:00:00+05:30  1797.900024  1817.800049  1791.000000  1805.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-03-06 00:00:00+05:30  10896859        0.0           0.0
# 2026-03-09 00:00:00+05:30   8073518        0.0           0.0
# 2026-03-10 00:00:00+05:30  11741600        0.0           0.0
# 2026-03-11 00:00:00+05:30   9548404        0.0           0.0
# 2026-03-12 00:00:00+05:30   5868933        0.0           0.0

# %%
plt.figure(figsize=(15,5))
data['Close'].plot()
plt.title("airtel share Trend")
# Out:
# Text(0.5, 1.0, 'airtel share Trend')

# %%
plt.figure(figsize=(15,5))
data['Close'].plot(color = 'green')
plt.xlim("2023-01-01","2026-04-01")
plt.title("airtel share Trend 2024-01-01  to 2026-03-01")
plt.show()

# %% [markdown]
# # Time Resampling

# %%
data.resample('MS').median()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2016-03-01 00:00:00+05:30   295.712893   303.758803   293.600043   299.042267
# 2016-04-01 00:00:00+05:30   299.661166   306.021063   298.508697   300.642899
# 2016-05-01 00:00:00+05:30   304.292349   305.871635   299.298376   302.136826
# 2016-06-01 00:00:00+05:30   303.524031   306.447890   299.383712   303.929550
# 2016-07-01 00:00:00+05:30   312.359547   317.225518   309.521089   312.807709
# ...                                ...          ...          ...          ...
# 2025-11-01 00:00:00+05:30  2112.000000  2129.500000  2097.500000  2112.199951
# 2025-12-01 00:00:00+05:30  2097.500000  2113.549927  2081.800049  2098.750000
# 2026-01-01 00:00:00+05:30  2022.500000  2029.699951  2001.300049  2022.500000
# 2026-02-01 00:00:00+05:30  2011.000000  2025.599976  1986.750000  2001.000000
# 2026-03-01 00:00:00+05:30  1855.599976  1888.450012  1832.299988  1868.750000
#
#                                Volume  Dividends  Stock Splits
# Date
# 2016-03-01 00:00:00+05:30   4295537.5        0.0           0.0
# 2016-04-01 00:00:00+05:30   3340975.0        0.0           0.0
# 2016-05-01 00:00:00+05:30   2889045.5        0.0           0.0
# 2016-06-01 00:00:00+05:30   2675626.5        0.0           0.0
# 2016-07-01 00:00:00+05:30   2498734.5        0.0           0.0
# ...                               ...        ...           ...
# 2025-11-01 00:00:00+05:30   7452899.0        0.0           0.0
# 2025-12-01 00:00:00+05:30   4218972.0        0.0           0.0
# 2026-01-01 00:00:00+05:30   5534929.0        0.0           0.0
# 2026-02-01 00:00:00+05:30   7430645.5        0.0           0.0
# 2026-03-01 00:00:00+05:30  11147788.0        0.0           0.0
#
# [121 rows x 7 columns]

# %%
plt.figure(figsize=(15,5))
data.resample('MS').max()['Close'].plot()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5))
data['Close'].plot()
data['Close'].rolling(14).mean().plot()
plt.title("airtel share Trend")
# Out:
# Text(0.5, 1.0, 'airtel share Trend')

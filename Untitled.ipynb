# %%
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
airtel = yf.Ticker("BHARTIARTL.NS")
data = airtel.history(period="5y")  # last 1 year
data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2021-03-12 00:00:00+05:30   508.982174   511.092709   500.348014   502.890259
# 2021-03-15 00:00:00+05:30   506.343915   506.343915   495.407346   501.595154
# 2021-03-16 00:00:00+05:30   502.698318   512.051956   502.698318   507.782867
# 2021-03-17 00:00:00+05:30   507.303272   509.413866   497.901672   501.643127
# 2021-03-18 00:00:00+05:30   508.310586   510.565064   494.400060   505.768341
# ...                                ...          ...          ...          ...
# 2026-03-05 00:00:00+05:30  1919.000000  1929.099976  1897.199951  1907.000000
# 2026-03-06 00:00:00+05:30  1900.000000  1902.099976  1867.099976  1870.800049
# 2026-03-09 00:00:00+05:30  1831.000000  1872.400024  1818.099976  1866.699951
# 2026-03-10 00:00:00+05:30  1880.800049  1881.000000  1846.500000  1850.400024
# 2026-03-11 00:00:00+05:30  1841.000000  1847.699951  1799.500000  1807.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-03-12 00:00:00+05:30  11624491        0.0           0.0
# 2021-03-15 00:00:00+05:30  10875944        0.0           0.0
# 2021-03-16 00:00:00+05:30  13252045        0.0           0.0
# 2021-03-17 00:00:00+05:30   8482758        0.0           0.0
# 2021-03-18 00:00:00+05:30  12465338        0.0           0.0
# ...                             ...        ...           ...
# 2026-03-05 00:00:00+05:30  11398717        0.0           0.0
# 2026-03-06 00:00:00+05:30  10896859        0.0           0.0
# 2026-03-09 00:00:00+05:30   8073518        0.0           0.0
# 2026-03-10 00:00:00+05:30  11741600        0.0           0.0
# 2026-03-11 00:00:00+05:30   9547012        0.0           0.0
#
# [1236 rows x 7 columns]

# %%
#data.reset_index(inplace=True)

# %%
#data['Date']=pd.to_datetime(data['Date'])

# %%
#data

# %%
#data['Date']=data['Date'].dt.date

# %%
#data['Date']=pd.to_datetime(data['Date'])

# %%
#data.to_excel("ITC.xlsx")

# %%
data.index=pd.to_datetime(data.index)

# %%
data.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2026-03-05 00:00:00+05:30  1919.000000  1929.099976  1897.199951  1907.000000
# 2026-03-06 00:00:00+05:30  1900.000000  1902.099976  1867.099976  1870.800049
# 2026-03-09 00:00:00+05:30  1831.000000  1872.400024  1818.099976  1866.699951
# 2026-03-10 00:00:00+05:30  1880.800049  1881.000000  1846.500000  1850.400024
# 2026-03-11 00:00:00+05:30  1841.000000  1847.699951  1799.500000  1807.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-03-05 00:00:00+05:30  11398717        0.0           0.0
# 2026-03-06 00:00:00+05:30  10896859        0.0           0.0
# 2026-03-09 00:00:00+05:30   8073518        0.0           0.0
# 2026-03-10 00:00:00+05:30  11741600        0.0           0.0
# 2026-03-11 00:00:00+05:30   9547012        0.0           0.0

# %%
plt.figure(figsize=(15,5))
data['Close'].plot()
plt.title("airtel share Trend")
# Out:
# Text(0.5, 1.0, 'airtel share Trend')

# %%
plt.figure(figsize=(15,5))
data['Close'].plot(color = 'green')
plt.xlim("2023-01-01","2026-04-01")
plt.title("airtel share Trend 2024-01-01  to 2026-03-01")
plt.show()

# %% [markdown]
# # Time Resampling

# %%
data.resample('MS').median()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2021-03-01 00:00:00+05:30   506.535777   510.565064   497.901672   502.362610
# 2021-04-01 00:00:00+05:30   510.612989   516.944780   504.665020   512.579712
# 2021-05-01 00:00:00+05:30   520.638215   535.028448   510.181322   520.926056
# 2021-06-01 00:00:00+05:30   515.385774   518.935401   509.245948   513.970795
# 2021-07-01 00:00:00+05:30   510.852880   515.649650   504.569171   508.502502
# ...                                ...          ...          ...          ...
# 2025-11-01 00:00:00+05:30  2112.000000  2129.500000  2097.500000  2112.199951
# 2025-12-01 00:00:00+05:30  2097.500000  2113.549927  2081.800049  2098.750000
# 2026-01-01 00:00:00+05:30  2022.500000  2029.699951  2001.300049  2022.500000
# 2026-02-01 00:00:00+05:30  2011.000000  2025.599976  1986.750000  2001.000000
# 2026-03-01 00:00:00+05:30  1861.099976  1895.900024  1846.500000  1870.800049
#
#                                Volume  Dividends  Stock Splits
# Date
# 2021-03-01 00:00:00+05:30  11624491.0        0.0           0.0
# 2021-04-01 00:00:00+05:30   8846896.0        0.0           0.0
# 2021-05-01 00:00:00+05:30  11294206.0        0.0           0.0
# 2021-06-01 00:00:00+05:30   7521071.5        0.0           0.0
# 2021-07-01 00:00:00+05:30   8138019.0        0.0           0.0
# ...                               ...        ...           ...
# 2025-11-01 00:00:00+05:30   7452899.0        0.0           0.0
# 2025-12-01 00:00:00+05:30   4218972.0        0.0           0.0
# 2026-01-01 00:00:00+05:30   5534929.0        0.0           0.0
# 2026-02-01 00:00:00+05:30   7430645.5        0.0           0.0
# 2026-03-01 00:00:00+05:30  11398717.0        0.0           0.0
#
# [61 rows x 7 columns]

# %%
plt.figure(figsize=(15,5))
data.resample('MS').max()['Close'].plot()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5))
data['Close'].plot()
data['Close'].rolling(14).mean().plot()
plt.title("airtel share Trend")
# Out:
# Text(0.5, 1.0, 'airtel share Trend')

# %%
import yfinance as yf
zudus = yf.Ticker("ZYDUSLIFE.BO")
data = zudus.history(period="5y")  # last 1 year
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-03-09 00:00:00+05:30  441.373604  442.931170  429.740594  431.736206
# 2021-03-10 00:00:00+05:30  434.169894  437.966441  431.736206  436.408875
# 2021-03-12 00:00:00+05:30  437.966436  439.037264  429.302513  430.762726
# 2021-03-15 00:00:00+05:30  424.435145  431.200809  419.324401  428.134338
# 2021-03-16 00:00:00+05:30  428.134336  431.006099  423.461667  428.231689
# ...                               ...         ...         ...         ...
# 2026-03-02 00:00:00+05:30  835.849976  911.799988  835.849976  906.849976
# 2026-03-04 00:00:00+05:30  899.150024  904.099976  889.000000  896.549988
# 2026-03-05 00:00:00+05:30  895.950012  917.799988  895.950012  914.450012
# 2026-03-06 00:00:00+05:30  909.450012  919.549988  906.799988  912.950012
# 2026-03-09 00:00:00+05:30  890.049988  911.400024  886.500000  908.650024
#
#                            Volume  Dividends  Stock Splits
# Date
# ...
